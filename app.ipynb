# %%
from flask import Flask, request, render_template
import nbimporter
from FYP_csv_model import connect_and_predict

# %%
app1 = Flask(__name__)

# %%
@app1.route('/data', methods=['GET'])
def get_data():
    result = connect_and_predict()
    print(result)

# %%
if __name__ == "__main__":
    app1.run()

# %%
app1.run(port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# Starting real-time data prediction...
#
# Predicted Emotional State: Sad, Predicted Stress Level: NoStress
# Temperature Difference: 2.00
# Humidity Difference: -5.08
# Heart Rate Difference: -80.00
# Oxygen Difference: -98.00
# GSR Difference: -0.02
# Body Temperature Difference: 1.14
#
# Predicted Emotional State: Sad, Predicted Stress Level: NoStress
# Temperature Difference: 2.01
# Humidity Difference: -5.11
# Heart Rate Difference: -80.00
# Oxygen Difference: -98.00
# GSR Difference: -1.02
# Body Temperature Difference: 1.15
#
# Predicted Emotional State: Sad, Predicted Stress Level: NoStress
# Temperature Difference: 2.00
# Humidity Difference: -5.05
# Heart Rate Difference: -80.00
# Oxygen Difference: -98.00
# GSR Difference: -1.02
# ...
